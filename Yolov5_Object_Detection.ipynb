# %% [markdown]
# # Yolov5

# %% [markdown]
# ## Setup

# %%
# !cd

# %% [markdown]
# #### Clone YOLOv5 Repository

# %%
# clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5

# %%
# !nvidia-smi

# %% [markdown]
# #### Import Library

# %%
import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %% [markdown]
# #### Check Directory

# %%
# %cd /Yolo/yolov5

# %%
# !cd

# %% [markdown]
# ## AP Image

# %% [markdown]
# #### Model Training

# %%
# !yolo train model=yolov5su.pt data=data.yaml epochs=100 imgsz=640 device=0 batch=4 patience=10

# %% [markdown]
# #### Model Validation

# %%
# !yolo task=detect mode=val model=./runs/detect/train/weights/best.pt data=data.yaml

# %% [markdown]
# #### Model Prediction

# %%
# !yolo task=detect mode=predict model=./runs/detect/train/weights/best.pt conf=0.25 source=/Yolo/datasets/test/images save=true save_txt=True save_crop=True save_conf=True

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'./runs/detect/predict/*.jpg')[:3]:
      display(Image(filename=image_path, height=600))
      print("\n")

# %% [markdown]
# ## LA Image

# %% [markdown]
# #### Model Training

# %%
# !yolo task=detect mode=train model=yolov5su.pt data=data_LA.yaml epochs=100 imgsz=640 device=0 batch=4 patience=10

# %% [markdown]
# #### Model Validation

# %%
# !yolo task=detect mode=val model=./runs/detect/train/weights/best.pt data=data_LA.yaml

# %% [markdown]
# #### Model Prediction

# %%
# !yolo task=detect mode=predict model=./runs/detect/train/weights/best.pt conf=0.25 source=/Yolo/datasets_LA/test/images save=true save_txt=True save_crop=True save_conf=True

# %% [markdown]
# #### Check Results

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'./runs/detect/predict/*.jpg')[:3]:
      display(Image(filename=image_path, height=600))
      print("\n")
