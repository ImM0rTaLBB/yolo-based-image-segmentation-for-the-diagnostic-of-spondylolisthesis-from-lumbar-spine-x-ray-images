# %% [markdown]
# ### Setup

# %%
# !pip install ultralytics

# %%
# !nvidia-smi

# %% [markdown]
# #### Import Library

# %%
import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# %cd H:\Yolo_Segmentation

# %%
# !cd

# %% [markdown]
# ### Segmentation Training

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data=data_LA.yaml epochs=100 imgsz=640 device=0 batch=4

# %% [markdown]
# ### Segmentation Validation

# %%
# !yolo task=segment mode=val model=./runs/segment/train/weights/best.pt data=data_LA.yaml

# %% [markdown]
# ### Segmentation Prediction

# %%
# !yolo task=segment mode=predict model=./runs/segment/train/weights/best.pt conf=0.25 source=./datasets_dn_LA/test/images save=true save_txt=True save_crop=True save_conf=True

# %% [markdown]
# #### Show Results

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'./runs/segment/predict/*.jpg')[:3]:
      display(Image(filename=image_path, height=600))
      print("\n")
